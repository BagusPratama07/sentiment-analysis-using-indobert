# %%
import pandas as pd

# %%
df = pd.read_csv('paslon1_2labeled.csv', sep=';')
print(df)
# Out:
#                                                    text sentimen
# 0     Pelaku seni Jateng pilih yang ga kaleng. Andik...  positif
# 1     Pagi tadi saya dan Mas Hendrar Prihadi bertemu...  positif
# 2     Memang benar kata pihak lawan pak Andika ini m...  positif
# 3     Pak Andika Perkasa selalu jadi idola di mana-m...  positif
# 4     Beruntungnya warga Jateng ini berkah.️ Hendi S...  positif
# ...                                                 ...      ...
# 1486  Tadi nonton debatnya Andika Hendi dan saya ter...  positif
# 1487  Gak sederhana tapi calon lain gak bisa . Pak H...  positif
# 1488  Pernyataan Penutup Andika-Hendi di Debat Pilka...  positif
# 1489  @jawafess biyen omahku ng smg utara banjire ng...  positif
# 1490  Luar biasa nih Jateng Pokoknya Andika yg punya...  positif
#
# [1491 rows x 2 columns]

# %%
df['text'] = df['text'].astype(str)
df
# Out:
#                                                    text sentimen
# 0     Pelaku seni Jateng pilih yang ga kaleng. Andik...  positif
# 1     Pagi tadi saya dan Mas Hendrar Prihadi bertemu...  positif
# 2     Memang benar kata pihak lawan pak Andika ini m...  positif
# 3     Pak Andika Perkasa selalu jadi idola di mana-m...  positif
# 4     Beruntungnya warga Jateng ini berkah.️ Hendi S...  positif
# ...                                                 ...      ...
# 1486  Tadi nonton debatnya Andika Hendi dan saya ter...  positif
# 1487  Gak sederhana tapi calon lain gak bisa . Pak H...  positif
# 1488  Pernyataan Penutup Andika-Hendi di Debat Pilka...  positif
# 1489  @jawafess biyen omahku ng smg utara banjire ng...  positif
# 1490  Luar biasa nih Jateng Pokoknya Andika yg punya...  positif
#
# [1491 rows x 2 columns]

# %%
df = df[['text', 'sentimen' ]]
df
# Out:
#                                                    text sentimen
# 0     Pelaku seni Jateng pilih yang ga kaleng. Andik...  positif
# 1     Pagi tadi saya dan Mas Hendrar Prihadi bertemu...  positif
# 2     Memang benar kata pihak lawan pak Andika ini m...  positif
# 3     Pak Andika Perkasa selalu jadi idola di mana-m...  positif
# 4     Beruntungnya warga Jateng ini berkah.️ Hendi S...  positif
# ...                                                 ...      ...
# 1486  Tadi nonton debatnya Andika Hendi dan saya ter...  positif
# 1487  Gak sederhana tapi calon lain gak bisa . Pak H...  positif
# 1488  Pernyataan Penutup Andika-Hendi di Debat Pilka...  positif
# 1489  @jawafess biyen omahku ng smg utara banjire ng...  positif
# 1490  Luar biasa nih Jateng Pokoknya Andika yg punya...  positif
#
# [1491 rows x 2 columns]

# %%
df = df.drop_duplicates(subset=['text'])
df = df.reset_index(drop=True)
df
# Out:
#                                                    text sentimen
# 0     Pelaku seni Jateng pilih yang ga kaleng. Andik...  positif
# 1     Pagi tadi saya dan Mas Hendrar Prihadi bertemu...  positif
# 2     Memang benar kata pihak lawan pak Andika ini m...  positif
# 3     Pak Andika Perkasa selalu jadi idola di mana-m...  positif
# 4     Beruntungnya warga Jateng ini berkah.️ Hendi S...  positif
# ...                                                 ...      ...
# 1424  Tadi nonton debatnya Andika Hendi dan saya ter...  positif
# 1425  Gak sederhana tapi calon lain gak bisa . Pak H...  positif
# 1426  Pernyataan Penutup Andika-Hendi di Debat Pilka...  positif
# 1427  @jawafess biyen omahku ng smg utara banjire ng...  positif
# 1428  Luar biasa nih Jateng Pokoknya Andika yg punya...  positif
#
# [1429 rows x 2 columns]

# %% [markdown]
# ## Text Cleaning

# %%
import re

def clean_text(text):
  if isinstance(text, str):
      # URLs
      text = re.sub(r'http\S+', '', text)
      # mentions
      text = re.sub(r'@\S+', '', text)
      # hashtags
      text = re.sub(r'#\S+', '', text)
      # special characters
      text = re.sub(r'[^\w\s]', '', text)
      # extra spaces
      text = re.sub(r'\s+', ' ', text).strip()
      # Ubah ke huruf kecil
      text = text.lower()
      # Hapus angka
      text = re.sub(r'\d+', '', text)

  else:
    # non-string values
    text = ''
  return text

df['cleaned_text'] = df['text'].apply(clean_text)

# Calculate the number of missing words for each row
df['missing_words'] = df.apply(lambda row: len(row['text'].split()) - len(row['cleaned_text'].split()), axis=1)
df
# Out:
#                                                    text sentimen  \
# 0     Pelaku seni Jateng pilih yang ga kaleng. Andik...  positif
# 1     Pagi tadi saya dan Mas Hendrar Prihadi bertemu...  positif
# 2     Memang benar kata pihak lawan pak Andika ini m...  positif
# 3     Pak Andika Perkasa selalu jadi idola di mana-m...  positif
# 4     Beruntungnya warga Jateng ini berkah.️ Hendi S...  positif
# ...                                                 ...      ...
# 1424  Tadi nonton debatnya Andika Hendi dan saya ter...  positif
# 1425  Gak sederhana tapi calon lain gak bisa . Pak H...  positif
# 1426  Pernyataan Penutup Andika-Hendi di Debat Pilka...  positif
# 1427  @jawafess biyen omahku ng smg utara banjire ng...  positif
# 1428  Luar biasa nih Jateng Pokoknya Andika yg punya...  positif
#
#                                            cleaned_text  missing_words
# 0     pelaku seni jateng pilih yang ga kaleng andika...              0
# 1     pagi tadi saya dan mas hendrar prihadi bertemu...              1
# 2     memang benar kata pihak lawan pak andika ini m...              1
# 3     pak andika perkasa selalu jadi idola di manama...              1
# 4     beruntungnya warga jateng ini berkah hendi seb...              3
# ...                                                 ...            ...
# 1424  tadi nonton debatnya andika hendi dan saya ter...              2
# 1425  gak sederhana tapi calon lain gak bisa pak hen...              2
# 1426  pernyataan penutup andikahendi di debat pilkad...              7
# 1427  biyen omahku ng smg utara banjire ngeriii udan...              2
# 1428  luar biasa nih jateng pokoknya andika yg punya...              2
#
# [1429 rows x 4 columns]

# %%
total_missing_words = df['missing_words'].sum()
print(f"Total banyak kata yang hilang: {total_missing_words}")
# Out:
# Total banyak kata yang hilang: 2981

# %%
cleaned_count = sum(df['cleaned_text'] != df['text'])
print(f"Banyak data yang dibersihkan: {cleaned_count}")
# Out:
# Banyak data yang dibersihkan: 1425

# %% [markdown]
# ## Case Folding

# %%
df['case_folding'] = df['cleaned_text'].str.lower()
df
# Out:
#                                                    text sentimen  \
# 0     Pelaku seni Jateng pilih yang ga kaleng. Andik...  positif
# 1     Pagi tadi saya dan Mas Hendrar Prihadi bertemu...  positif
# 2     Memang benar kata pihak lawan pak Andika ini m...  positif
# 3     Pak Andika Perkasa selalu jadi idola di mana-m...  positif
# 4     Beruntungnya warga Jateng ini berkah.️ Hendi S...  positif
# ...                                                 ...      ...
# 1424  Tadi nonton debatnya Andika Hendi dan saya ter...  positif
# 1425  Gak sederhana tapi calon lain gak bisa . Pak H...  positif
# 1426  Pernyataan Penutup Andika-Hendi di Debat Pilka...  positif
# 1427  @jawafess biyen omahku ng smg utara banjire ng...  positif
# 1428  Luar biasa nih Jateng Pokoknya Andika yg punya...  positif
#
#                                            cleaned_text  missing_words  \
# 0     pelaku seni jateng pilih yang ga kaleng andika...              0
# 1     pagi tadi saya dan mas hendrar prihadi bertemu...              1
# 2     memang benar kata pihak lawan pak andika ini m...              1
# 3     pak andika perkasa selalu jadi idola di manama...              1
# 4     beruntungnya warga jateng ini berkah hendi seb...              3
# ...                                                 ...            ...
# 1424  tadi nonton debatnya andika hendi dan saya ter...              2
# 1425  gak sederhana tapi calon lain gak bisa pak hen...              2
# 1426  pernyataan penutup andikahendi di debat pilkad...              7
# 1427  biyen omahku ng smg utara banjire ngeriii udan...              2
# 1428  luar biasa nih jateng pokoknya andika yg punya...              2
#
#                                            case_folding
# 0     pelaku seni jateng pilih yang ga kaleng andika...
# 1     pagi tadi saya dan mas hendrar prihadi bertemu...
# 2     memang benar kata pihak lawan pak andika ini m...
# 3     pak andika perkasa selalu jadi idola di manama...
# 4     beruntungnya warga jateng ini berkah hendi seb...
# ...                                                 ...
# 1424  tadi nonton debatnya andika hendi dan saya ter...
# 1425  gak sederhana tapi calon lain gak bisa pak hen...
# 1426  pernyataan penutup andikahendi di debat pilkad...
# 1427  biyen omahku ng smg utara banjire ngeriii udan...
# 1428  luar biasa nih jateng pokoknya andika yg punya...
#
# [1429 rows x 5 columns]

# %% [markdown]
# ##Spell Normalized

# %%
# Load kamus alay
kamus_alay = pd.read_csv("https://raw.githubusercontent.com/nasalsabila/kamus-alay/master/colloquial-indonesian-lexicon.csv")
alay_dict = pd.Series(kamus_alay['formal'].values, index=kamus_alay['slang']).to_dict()

# Load kamus kbba.txt
kamus_kbba = pd.read_csv('kbba.txt', sep='\t')
kbba_dict = pd.Series(kamus_kbba['tujuan'].values, index=kamus_kbba['7an']).to_dict()

# Load kamus slang.csv
kamus_slang = pd.read_csv('kamus_slang.csv')
slang_dict = pd.Series(kamus_slang['formal'].values, index=kamus_slang['slang']).to_dict()

# Load kamus slangword.txt
kamus_sw = pd.read_csv('slangword.txt', sep=':', engine='python', header=None, names=['slang', 'formal'])
sw_dict = pd.Series(kamus_sw['formal'].values, index=kamus_sw['slang']).to_dict()

# Gabungkan semua kamus
all_dicts = [alay_dict, kbba_dict, slang_dict, sw_dict]
combined_dict = {}
for d in all_dicts:
    combined_dict.update(d)

# Fungsi untuk normalisasi teks
def normalize_text(text):
    normalized_text = []
    for word in text.split():
        if word in combined_dict:
            normalized_text.append(combined_dict[word])
        else:
            normalized_text.append(word)
    return ' '.join(normalized_text)

df['normalized_text'] = df['case_folding'].apply(normalize_text)
df
def normalize_text(text):
    normalized_text = []
    normalized_count = 0  # Initialize a counter for normalized words
    for word in text.split():
        if word in combined_dict:
            normalized_text.append(combined_dict[word])
            normalized_count += 1  # Increment the counter if word is normalized
        else:
            normalized_text.append(word)
    return ' '.join(normalized_text), normalized_count  # Return both normalized text and count

df['normalized_text'], df['normalized_count'] = zip(*df['case_folding'].apply(normalize_text))
df
# Out:
#                                                    text sentimen  \
# 0     Pelaku seni Jateng pilih yang ga kaleng. Andik...  positif
# 1     Pagi tadi saya dan Mas Hendrar Prihadi bertemu...  positif
# 2     Memang benar kata pihak lawan pak Andika ini m...  positif
# 3     Pak Andika Perkasa selalu jadi idola di mana-m...  positif
# 4     Beruntungnya warga Jateng ini berkah.️ Hendi S...  positif
# ...                                                 ...      ...
# 1424  Tadi nonton debatnya Andika Hendi dan saya ter...  positif
# 1425  Gak sederhana tapi calon lain gak bisa . Pak H...  positif
# 1426  Pernyataan Penutup Andika-Hendi di Debat Pilka...  positif
# 1427  @jawafess biyen omahku ng smg utara banjire ng...  positif
# 1428  Luar biasa nih Jateng Pokoknya Andika yg punya...  positif
#
#                                            cleaned_text  missing_words  \
# 0     pelaku seni jateng pilih yang ga kaleng andika...              0
# 1     pagi tadi saya dan mas hendrar prihadi bertemu...              1
# 2     memang benar kata pihak lawan pak andika ini m...              1
# 3     pak andika perkasa selalu jadi idola di manama...              1
# 4     beruntungnya warga jateng ini berkah hendi seb...              3
# ...                                                 ...            ...
# 1424  tadi nonton debatnya andika hendi dan saya ter...              2
# 1425  gak sederhana tapi calon lain gak bisa pak hen...              2
# 1426  pernyataan penutup andikahendi di debat pilkad...              7
# 1427  biyen omahku ng smg utara banjire ngeriii udan...              2
# 1428  luar biasa nih jateng pokoknya andika yg punya...              2
#
#                                            case_folding  \
# 0     pelaku seni jateng pilih yang ga kaleng andika...
# 1     pagi tadi saya dan mas hendrar prihadi bertemu...
# 2     memang benar kata pihak lawan pak andika ini m...
# 3     pak andika perkasa selalu jadi idola di manama...
# 4     beruntungnya warga jateng ini berkah hendi seb...
# ...                                                 ...
# 1424  tadi nonton debatnya andika hendi dan saya ter...
# 1425  gak sederhana tapi calon lain gak bisa pak hen...
# 1426  pernyataan penutup andikahendi di debat pilkad...
# 1427  biyen omahku ng smg utara banjire ngeriii udan...
# 1428  luar biasa nih jateng pokoknya andika yg punya...
#
#                                         normalized_text  normalized_count
# 0     pelaku seni jateng pilih yang enggak kaleng an...                 1
# 1     pagi tadi saya dan mas hendrar prihadi bertemu...                 0
# 2     memang benar kata pihak lawan pak andika ini m...                 0
# 3     pak andika perkasa selalu jadi idola di manama...                 0
# 4     beruntungnya warga jateng ini berkah hendi seb...                 0
# ...                                                 ...               ...
# 1424  tadi menonton debatnya andika hendi dan saya t...                 2
# 1425  enggak sederhana tapi calon lain enggak bisa p...                 3
# 1426  pernyataan penutup andikahendi di debat pemili...                 1
# 1427  biyen omahku ng semoga utara banjire ngeriii u...                 4
# 1428  luar biasa ini jateng pokoknya andika yang pun...                 4
#
# [1429 rows x 7 columns]

# %%
total_normalized_words = df['normalized_count'].sum()
print(f"Total kata yang dinormalisasi: {total_normalized_words}")
# Out:
# Total kata yang dinormalisasi: 1524

# %%
normalized_count = sum(df['case_folding'] != df['normalized_text'])
print(f"Banyak data yang dinormalisasi: {normalized_count}")
# Out:
# Banyak data yang dinormalisasi: 860
